# %% [markdown]
# # CAN Workshop- LFADS demo in pytorch

# %% [markdown]
# ## Import necessary modules

# %%
# %matplotlib inline

import torch
import torchvision
np = torch._np
import matplotlib.pyplot as plt

import os
import yaml

from lfads import LFADS_Net
from utils import read_data, load_parameters, save_parameters

# plt.style.use('dark_background')

# %%
# Select device to train LFADS on
device = 'cuda' if torch.cuda.is_available() else 'cpu'; print('Using device: %s'%device)
# Out:
# Using device: cuda

# %% [markdown]
# ## Load or Generate Data

# %%
if os.path.exists('./synth_data/chaotic_rnn_300'):
    data_dict = read_data('./synth_data/chaotic_rnn_300')
else:
    if not os.path.isdir('./synth_data'):
        os.mkdir('./synth_data/')
    
    from synth_data_chaotic_rnn import generate_data
    data_dict = generate_data(T= 1, dt_rnn= 0.01, dt_cal= 0.01,
                              Ninits= 400, Ntrial= 10, Ncells= 50, trainp= 0.8,
                              tau=0.025, gamma=1.5, maxRate=30, B=20,
                              seed=300, save=True)

train_data = torch.Tensor(data_dict['train_spikes']).to(device)
valid_data = torch.Tensor(data_dict['valid_spikes']).to(device)

train_truth = torch.Tensor(data_dict['train_rates']).to(device)
valid_truth = torch.tensor(data_dict['valid_rates']).to(device)

train_ds      = torch.utils.data.TensorDataset(train_data)
valid_ds      = torch.utils.data.TensorDataset(valid_data)

num_trials, num_steps, num_cells = train_data.shape
print(train_data.shape)
# Out:
# torch.Size([3200, 100, 50])

# %% [markdown]
# ## View Example Trial

# %%
plt.figure(figsize = (12,12))
plt.imshow(data_dict['train_spikes'][0].T, cmap=plt.cm.Greys)
plt.xticks(np.linspace(0, 100, 6), ['%.1f'%i for i in np.linspace(0, 1, 6)])
plt.xlabel('Time (s)')
plt.ylabel('Cell #')
plt.colorbar(orientation='horizontal', label='# Spikes in 0.01 s time bin')
plt.title('Example trial');

# %% [markdown]
# ## View example Ground Truth Firing Rates

# %%
plt.figure(figsize = (12,12))
plt.imshow(data_dict['train_rates'][0].T, cmap=plt.cm.plasma)
plt.xticks(np.linspace(0, 100, 6), ['%.1f'%i for i in np.linspace(0, 1, 6)])
plt.xlabel('Time (s)')
plt.ylabel('Cell #')
plt.colorbar(orientation='horizontal', label='Firing Rate (Hz)')
plt.title('Example trial');

# %% [markdown]
# ## LFADS Schema
# <img src='lfads_schema.png' width=800 align=left>

# %% [markdown]
# ## Load model hyperparameters

# %%
hyperparams = load_parameters('./parameters_demo.yaml')
save_parameters(hyperparams)
hyperparams
# Out:
# {'betas': (0.9, 0.99),
#  'c_encoder_dim': 128,
#  'clip_val': 5.0,
#  'controller_dim': 128,
#  'dataset_name': 'chaotic_rnn',
#  'epsilon': 0.1,
#  'factors_dim': 20,
#  'g0_encoder_dim': 200,
#  'g0_prior_kappa': 0.1,
#  'g_dim': 200,
#  'keep_prob': 0.95,
#  'kl_weight_schedule_dur': 2000,
#  'kl_weight_schedule_start': 0,
#  'l2_con_scale': 0,
#  'l2_gen_scale': 2000,
#  'l2_weight_schedule_dur': 2000,
#  'l2_weight_schedule_start': 0,
#  'learning_rate': 0.01,
#  'learning_rate_decay': 0.95,
#  'learning_rate_min': 1e-05,
#  'max_norm': 200,
#  'run_name': 'demo',
#  'scheduler_cooldown': 6,
#  'scheduler_on': True,
#  'scheduler_patience': 6,
#  'u_dim': 1,
#  'u_prior_kappa': 0.1}

# %% [markdown]
# ## Instantiate LFADS model

# %%
model = LFADS_Net(inputs_dim = num_cells, T = num_steps, dt = 0.01, device=device,
                 model_hyperparams=hyperparams).to(device)
# Out:
# Random seed: 3769

# %% [markdown]
# #### Pick up where you left off (if you have a recent save)

# %%
# model.load_checkpoint('recent')

# %% [markdown]
# ## Fit model
#
# Rule of thumb: You can usually see good fit after 200 epochs (~30 mins runtime on Thinkpad GPU, ~2.5 hours on CPU), but to see good inference of perturbation timings need to run for about 800 epochs (~2 hours on Thinkpad GPU).

# %%
model.fit(train_ds, valid_ds, max_epochs=200, batch_size=200, use_tensorboard=True,
          train_truth=train_truth, valid_truth=valid_truth)
# Out:
# Beginning training...
# Epoch:    1, Step:    16, training loss: 2678.004, validation loss: 3340.258
# Epoch:    2, Step:    32, training loss: 2231.734, validation loss: 2650.122
# Epoch:    3, Step:    48, training loss: 2155.342, validation loss: 2370.744
# Epoch:    4, Step:    64, training loss: 2132.817, validation loss: 2301.345
# Epoch:    5, Step:    80, training loss: 2122.175, validation loss: 2266.808
# Epoch:    6, Step:    96, training loss: 2116.106, validation loss: 2259.606
# Epoch:    7, Step:   112, training loss: 2108.942, validation loss: 2256.436
# Epoch:    8, Step:   128, training loss: 2107.156, validation loss: 2292.228
# Epoch:    9, Step:   144, training loss: 2115.339, validation loss: 2252.597
# Epoch:   10, Step:   160, training loss: 2108.981, validation loss: 2240.514
# Epoch:   11, Step:   176, training loss: 2105.172, validation loss: 2224.779
# Epoch:   12, Step:   192, training loss: 2106.449, validation loss: 2220.495
# Epoch:   13, Step:   208, training loss: 2102.512, validation loss: 2211.007
# Epoch:   14, Step:   224, training loss: 2101.645, validation loss: 2206.508
# Epoch:   15, Step:   240, training loss: 2102.310, validation loss: 2197.432
# Epoch:   16, Step:   256, training loss: 2100.418, validation loss: 2198.296
# Epoch:   17, Step:   272, training loss: 2117.209, validation loss: 2198.627
# Learning rate decreased to 0.00950000
# Epoch:   18, Step:   288, training loss: 2106.629, validation loss: 2191.961
# Epoch:   19, Step:   304, training loss: 2102.009, validation loss: 2181.693
# Epoch:   20, Step:   320, training loss: 2099.631, validation loss: 2179.839
# Epoch:   21, Step:   336, training loss: 2098.889, validation loss: 2176.537
# Epoch:   22, Step:   352, training loss: 2098.152, validation loss: 2175.256
# Epoch:   23, Step:   368, training loss: 2121.439, validation loss: 2187.724
# Learning rate decreased to 0.00902500
# Epoch:   24, Step:   384, training loss: 2106.200, validation loss: 2173.712
# Epoch:   25, Step:   400, training loss: 2100.474, validation loss: 2167.109
# Epoch:   26, Step:   416, training loss: 2097.828, validation loss: 2165.925
# Epoch:   27, Step:   432, training loss: 2096.880, validation loss: 2161.138
# Epoch:   28, Step:   448, training loss: 2096.239, validation loss: 2160.203
# Epoch:   29, Step:   464, training loss: 2096.243, validation loss: 2158.463
# Epoch:   30, Step:   480, training loss: 2095.395, validation loss: 2156.401
# Epoch:   31, Step:   496, training loss: 2095.566, validation loss: 2156.017
# Epoch:   32, Step:   512, training loss: 2097.717, validation loss: 2155.564
# Epoch:   33, Step:   528, training loss: 2097.149, validation loss: 2150.962
# Epoch:   34, Step:   544, training loss: 2095.948, validation loss: 2149.736
# Epoch:   35, Step:   560, training loss: 2095.721, validation loss: 2149.063
# Epoch:  164, Step:  2624, training loss: 2116.255, validation loss: 2105.897
# Epoch:  165, Step:  2640, training loss: 2116.523, validation loss: 2105.384
# Epoch:  166, Step:  2656, training loss: 2116.442, validation loss: 2105.558
# Epoch:  167, Step:  2672, training loss: 2116.604, validation loss: 2105.641
# Epoch:  168, Step:  2688, training loss: 2116.695, validation loss: 2105.369
# Learning rate decreased to 0.00397214
# Epoch:  169, Step:  2704, training loss: 2116.654, validation loss: 2105.608
# Epoch:  170, Step:  2720, training loss: 2116.277, validation loss: 2105.969
# Epoch:  171, Step:  2736, training loss: 2116.000, validation loss: 2105.230
# Epoch:  172, Step:  2752, training loss: 2115.883, validation loss: 2104.939
# Epoch:  173, Step:  2768, training loss: 2116.131, validation loss: 2105.290
# Epoch:  174, Step:  2784, training loss: 2116.343, validation loss: 2105.812
# Epoch:  175, Step:  2800, training loss: 2116.168, validation loss: 2105.291
# Epoch:  176, Step:  2816, training loss: 2116.148, validation loss: 2105.624
# Epoch:  177, Step:  2832, training loss: 2116.173, validation loss: 2105.412
# Epoch:  178, Step:  2848, training loss: 2116.225, validation loss: 2105.312
# Epoch:  179, Step:  2864, training loss: 2116.438, validation loss: 2105.723
# Learning rate decreased to 0.00377354
# Epoch:  180, Step:  2880, training loss: 2115.900, validation loss: 2105.265
# Epoch:  181, Step:  2896, training loss: 2116.226, validation loss: 2105.575
# Epoch:  182, Step:  2912, training loss: 2115.904, validation loss: 2105.222
# Epoch:  183, Step:  2928, training loss: 2116.032, validation loss: 2105.217
# Epoch:  184, Step:  2944, training loss: 2115.986, validation loss: 2105.247
# Epoch:  185, Step:  2960, training loss: 2115.676, validation loss: 2105.433
# Epoch:  186, Step:  2976, training loss: 2115.824, validation loss: 2105.610
# Epoch:  187, Step:  2992, training loss: 2116.108, validation loss: 2104.906
# Epoch:  188, Step:  3008, training loss: 2115.985, validation loss: 2105.581
# Epoch:  189, Step:  3024, training loss: 2116.036, validation loss: 2105.446
# Epoch:  190, Step:  3040, training loss: 2116.200, validation loss: 2105.358
# Learning rate decreased to 0.00358486
# Epoch:  191, Step:  3056, training loss: 2115.903, validation loss: 2104.793
# Epoch:  192, Step:  3072, training loss: 2115.773, validation loss: 2105.395
# Epoch:  193, Step:  3088, training loss: 2115.602, validation loss: 2105.344
# Epoch:  194, Step:  3104, training loss: 2115.599, validation loss: 2105.113
# Epoch:  195, Step:  3120, training loss: 2115.772, validation loss: 2105.071
# Epoch:  196, Step:  3136, training loss: 2115.638, validation loss: 2105.074
# Epoch:  197, Step:  3152, training loss: 2115.513, validation loss: 2105.483
# Epoch:  198, Step:  3168, training loss: 2115.684, validation loss: 2104.633
# Epoch:  199, Step:  3184, training loss: 2115.594, validation loss: 2105.062
# Epoch:  200, Step:  3200, training loss: 2115.675, validation loss: 2104.921
# ...training complete.

# %% [markdown]
# ## Load checkpoint with lowest validation error

# %%
model.load_checkpoint('best')

# %% [markdown]
# ## Plot results summary

# %%
model.plot_summary(data=valid_data, truth=valid_truth)
# Out:
# {'factors': <Figure size 576x576 with 20 Axes>,
#  'inputs': <Figure size 576x108 with 1 Axes>,
#  'rsq': <Figure size 432x288 with 1 Axes>,
#  'traces': <Figure size 576x576 with 12 Axes>,
#  'truth': <Figure size 576x576 with 12 Axes>}
